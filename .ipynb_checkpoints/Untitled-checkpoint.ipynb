# %%
import pandas as pd

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Argentina      ARG  2020-12-29               700.0                NaN
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31             32013.0                NaN
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1262      Wales      NaN  2021-01-16                 NaN                NaN
# 1263      Wales      NaN  2021-01-17            151938.0           151737.0
# 1264      Wales      NaN  2021-01-18            162197.0           161932.0
# 1265      Wales      NaN  2021-01-19            176186.0           175816.0
# 1266      Wales      NaN  2021-01-20            190831.0           190435.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 1262                      NaN                     NaN              8931.0
# 1263                    201.0                     NaN              9403.0
# 1264                    265.0                 10259.0             10123.0
# 1265                    370.0                 13989.0             10672.0
# 1266                    396.0                 14645.0             11105.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                            NaN
# 1                                NaN                            NaN
# 2                               0.07                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 1262                             NaN                            NaN
# 1263                            4.82                           4.81
# 1264                            5.14                           5.14
# 1265                            5.59                           5.58
# 1266                            6.05                           6.04
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# ...                                   ...                             ...
# 1262                                  NaN                          2833.0
# 1263                                 0.01                          2982.0
# 1264                                 0.01                          3211.0
# 1265                                 0.01                          3385.0
# 1266                                 0.01                          3522.0
#
#                                  vaccines                       source_name  \
# 0                               Sputnik V                Ministry of Health
# 1                               Sputnik V                Ministry of Health
# 2                               Sputnik V                Ministry of Health
# 3                               Sputnik V                Ministry of Health
# 4                               Sputnik V                Ministry of Health
# ...                                   ...                               ...
# 1262  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1263  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1264  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1265  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1266  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 1262  https://coronavirus.data.gov.uk/details/health...
# 1263  https://coronavirus.data.gov.uk/details/health...
# 1264  https://coronavirus.data.gov.uk/details/health...
# 1265  https://coronavirus.data.gov.uk/details/health...
# 1266  https://coronavirus.data.gov.uk/details/health...
#
# [1267 rows x 15 columns]>

# %%
df.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1267 entries, 0 to 1266
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1267 non-null   object
#  1   iso_code                             1118 non-null   object
#  2   date                                 1267 non-null   object
#  3   total_vaccinations                   825 non-null    float64
#  4   people_vaccinated                    794 non-null    float64
#  5   people_fully_vaccinated              167 non-null    float64
#  6   daily_vaccinations_raw               655 non-null    float64
#  7   daily_vaccinations                   1210 non-null   float64
#  8   total_vaccinations_per_hundred       825 non-null    float64
#  9   people_vaccinated_per_hundred        794 non-null    float64
#  10  people_fully_vaccinated_per_hundred  167 non-null    float64
#  11  daily_vaccinations_per_million       1210 non-null   float64
#  12  vaccines                             1267 non-null   object
#  13  source_name                          1267 non-null   object
#  14  source_website                       1267 non-null   object
# dtypes: float64(9), object(6)
# memory usage: 148.6+ KB

# %%
dict_vaccines = {}
for vac in df['vaccines'].unique() :
    mask = (df['vaccines'] == vac)
    df_temp = df[mask]
    dict_vaccines["df_"+vac] = df_temp

# %%
df['iso_code'].value_counts(dropna=False)
df[df['iso_code'].isnull()]
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 335   England      NaN  2020-12-20            568044.0           568044.0
# 336   England      NaN  2020-12-21                 NaN                NaN
# 337   England      NaN  2020-12-22                 NaN                NaN
# 338   England      NaN  2020-12-23                 NaN                NaN
# 339   England      NaN  2020-12-24                 NaN                NaN
# ...       ...      ...         ...                 ...                ...
# 1262    Wales      NaN  2021-01-16                 NaN                NaN
# 1263    Wales      NaN  2021-01-17            151938.0           151737.0
# 1264    Wales      NaN  2021-01-18            162197.0           161932.0
# 1265    Wales      NaN  2021-01-19            176186.0           175816.0
# 1266    Wales      NaN  2021-01-20            190831.0           190435.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 335                       NaN                     NaN                 NaN
# 336                       NaN                     NaN             37625.0
# 337                       NaN                     NaN             37625.0
# 338                       NaN                     NaN             37625.0
# 339                       NaN                     NaN             37625.0
# ...                       ...                     ...                 ...
# 1262                      NaN                     NaN              8931.0
# 1263                    201.0                     NaN              9403.0
# 1264                    265.0                 10259.0             10123.0
# 1265                    370.0                 13989.0             10672.0
# 1266                    396.0                 14645.0             11105.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 335                             1.01                           1.01
# 336                              NaN                            NaN
# 337                              NaN                            NaN
# 338                              NaN                            NaN
# 339                              NaN                            NaN
# ...                              ...                            ...
# 1262                             NaN                            NaN
# 1263                            4.82                           4.81
# 1264                            5.14                           5.14
# 1265                            5.59                           5.58
# 1266                            6.05                           6.04
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 335                                   NaN                             NaN
# 336                                   NaN                           668.0
# 337                                   NaN                           668.0
# 338                                   NaN                           668.0
# 339                                   NaN                           668.0
# ...                                   ...                             ...
# 1262                                  NaN                          2833.0
# 1263                                 0.01                          2982.0
# 1264                                 0.01                          3211.0
# 1265                                 0.01                          3385.0
# 1266                                 0.01                          3522.0
#
#                                  vaccines                       source_name  \
# 335   Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 336   Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 337   Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 338   Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 339   Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# ...                                   ...                               ...
# 1262  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1263  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1264  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1265  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1266  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 335   https://coronavirus.data.gov.uk/details/health...
# 336   https://coronavirus.data.gov.uk/details/health...
# 337   https://coronavirus.data.gov.uk/details/health...
# 338   https://coronavirus.data.gov.uk/details/health...
# 339   https://coronavirus.data.gov.uk/details/health...
# ...                                                 ...
# 1262  https://coronavirus.data.gov.uk/details/health...
# 1263  https://coronavirus.data.gov.uk/details/health...
# 1264  https://coronavirus.data.gov.uk/details/health...
# 1265  https://coronavirus.data.gov.uk/details/health...
# 1266  https://coronavirus.data.gov.uk/details/health...
#
# [149 rows x 15 columns]

# %%
import geoplotlib

# %%
geoplotlib.dot(df['country'])
geoplotlib.show()
# Out:
# Traceback (most recent call last):
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\__init__.py", line 32, in _runapp
#     app.start()
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\core.py", line 364, in start
#     self.proj.fit(BoundingBox.from_bboxes([l.bbox() for l in self.geoplotlib_config.layers]),
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\core.py", line 364, in <listcomp>
#     self.proj.fit(BoundingBox.from_bboxes([l.bbox() for l in self.geoplotlib_config.layers]),
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\layers.py", line 159, in bbox
#     return BoundingBox.from_points(lons=self.data['lon'], lats=self.data['lat'])
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py", line 824, in __getitem__
#     return self._get_value(key)
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py", line 932, in _get_value
#     loc = self.index.get_loc(label)
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\range.py", line 354, in get_loc
#     raise KeyError(key)
# KeyError: 'lon'

# %%
thedata = df['iso_code']
geoplotlib.dot(thedata)
geoplotlib.show()
# Out:
# Traceback (most recent call last):
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\__init__.py", line 32, in _runapp
#     app.start()
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\core.py", line 364, in start
#     self.proj.fit(BoundingBox.from_bboxes([l.bbox() for l in self.geoplotlib_config.layers]),
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\core.py", line 364, in <listcomp>
#     self.proj.fit(BoundingBox.from_bboxes([l.bbox() for l in self.geoplotlib_config.layers]),
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\geoplotlib\layers.py", line 159, in bbox
#     return BoundingBox.from_points(lons=self.data['lon'], lats=self.data['lat'])
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py", line 824, in __getitem__
#     return self._get_value(key)
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py", line 932, in _get_value
#     loc = self.index.get_loc(label)
#   File "c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\range.py", line 354, in get_loc
#     raise KeyError(key)
# KeyError: 'lon'

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import get_provider, CARTODBPOSITRON
from bokeh.io import output_notebook, show

from pyproj import Proj, transform

inProj = Proj(init='epsg:3857')
outProj = Proj(init='epsg:4326')

world_lon1, world_lat1 = transform(outProj,inProj,-180,-85)
world_lon2, world_lat2 = transform(outProj,inProj,180,85)

cartodb = get_provider(CARTODBPOSITRON)

fig = figure(plot_width=800, plot_height=700,
             x_range=(world_lon1, world_lon2),
             y_range=(world_lat1, world_lat2),
             x_axis_type="mercator", y_axis_type="mercator")

fig.add_tile(cartodb)

show(fig)
# Out:
# c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\camil\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-51-355ec48ef7a1>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   world_lon1, world_lat1 = transform(outProj,inProj,-180,-85)
# <ipython-input-51-355ec48ef7a1>:11: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   world_lon2, world_lat2 = transform(outProj,inProj,180,85)

# %%
from bokeh.models import LogColorMapper
from bokeh.palettes import Oranges256 as oranges
